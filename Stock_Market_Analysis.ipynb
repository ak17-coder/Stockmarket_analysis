# %% [markdown]
# # 📈 Stock Market Analysis using Python
# In this notebook, we will visualize and analyze trends in stock prices using time series plots and moving averages.

# %%
# Install required packages (if not already installed)
# !pip install yfinance pandas matplotlib

# %%
# Import libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Download stock data (example: Apple)
stock = yf.download('AAPL', start='2020-01-01', end='2024-12-31')
stock.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14044\1080953292.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock = yf.download('AAPL', start='2020-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.620842  72.681289  71.373218  71.627092  135480400
# 2020-01-03  71.914818  72.676447  71.689957  71.847118  146322800
# 2020-01-06  72.487862  72.526549  70.783263  71.034724  118387200
# 2020-01-07  72.146950  72.753831  71.926922  72.497537  108872000
# 2020-01-08  73.307518  73.609752  71.849540  71.849540  132079200

# %%
# Plot Closing Price
plt.figure(figsize=(14, 6))
plt.plot(stock['Close'], label='Closing Price')
plt.title('AAPL Closing Price')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid()
plt.show()

# %%
# Calculate moving averages
stock['MA20'] = stock['Close'].rolling(window=20).mean()
stock['MA50'] = stock['Close'].rolling(window=50).mean()

# %%
# Plot Closing Price with Moving Averages
plt.figure(figsize=(14, 6))
plt.plot(stock['Close'], label='Closing Price')
plt.plot(stock['MA20'], label='20-Day MA')
plt.plot(stock['MA50'], label='50-Day MA')
plt.title('AAPL Stock Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14, 4))
plt.plot(stock['Volume'], color='gray')
plt.title('AAPL Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid()
plt.show()
